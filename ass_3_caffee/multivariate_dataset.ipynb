# %%
get_ipython().magic(u'matplotlib inline')
import numpy as np
import matplotlib.pyplot as plt

# for the same classes every time
#np.random.seed(9)
# size[0] - number of points
# size[1] - dimesion of points
n_classes=5
dimension=2
examples=200
# centers around which patterns will be distributed
means = np.random.uniform(1, 50, size=(n_classes, dimension))
# covariance matrices for each of classes
#stds = np.random.uniform(0, 0.2, size=n_classes)
covs = np.random.uniform(1, 5, size=(n_classes, dimension, dimension))
# generate array of n_classes arrays, each contains examples number of points
X = [np.random.multivariate_normal(mean, cov, examples) for mean, cov in zip(means, covs)]
X = np.vstack(X)
# generate array of three arrays for labeling
C = [[i] * examples for i in xrange(n_classes)]
C = np.ravel(C)

plt.figure()
plt.scatter(X[:,0], X[:,1], c=C)

np.savetxt('dataset.txt', X, fmt='%6.3f')
np.savetxt('classes.txt', C, fmt='%1.0f')

tests = 5
Xt = [np.random.multivariate_normal(mean, cov, tests) for mean, cov in zip(means, covs)]
Xt = np.vstack(Xt)
Ct = [[i] * tests for i in xrange(n_classes)]
Ct = np.ravel(Ct)
plt.figure()
plt.scatter(Xt[:,0], Xt[:,1], c=Ct)
np.savetxt('test_dataset.txt', Xt, fmt='%6.3f')
# Out:
# /home/local/stud/adilova/mypy/lib/python2.7/site-packages/ipykernel/__main__.py:18: RuntimeWarning: covariance is not positive-semidefinite.
# /home/local/stud/adilova/mypy/lib/python2.7/site-packages/ipykernel/__main__.py:31: RuntimeWarning: covariance is not positive-semidefinite.

# %%
test_data = np.loadtxt('test_dataset1.txt')
test_data = np.transpose(np.delete(test_data, (0), axis=0))

result = np.loadtxt('result.txt')
result = [ int(x) for x in result ]

plt.scatter(test_data[0], test_data[1], c=result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-81507e07d7f8> in <module>()
#       5 result = [ int(x) for x in result ]
#       6
# ----> 7 plt.scatter(test_data[0], test_data[1], c=result)
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3249                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3250                          linewidths=linewidths, verts=verts,
# -> 3251                          edgecolors=edgecolors, data=data, **kwargs)
#    3252     finally:
#    3253         ax.hold(washold)
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3887                 offsets=offsets,
#    3888                 transOffset=kwargs.pop('transform', self.transData),
# -> 3889                 alpha=alpha
#    3890                 )
#    3891         collection.set_transform(mtransforms.IdentityTransform())
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     829         """
#     830
# --> 831         Collection.__init__(self, **kwargs)
#     832         self.set_paths(paths)
#     833         self.set_sizes(sizes)
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     115
#     116         self.set_edgecolor(edgecolors)
# --> 117         self.set_facecolor(facecolors)
#     118         self.set_linewidth(linewidths)
#     119         self.set_linestyle(linestyles)
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/collections.pyc in set_facecolor(self, c)
#     610             c = mpl.rcParams['patch.facecolor']
#     611         self._facecolors_original = c
# --> 612         self._facecolors = mcolors.colorConverter.to_rgba_array(c, self._alpha)
#     613         self.stale = True
#     614
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(self, c, alpha)
#     420             result = np.zeros((nc, 4), dtype=np.float)
#     421             for i, cc in enumerate(c):
# --> 422                 result[i] = self.to_rgba(cc, alpha)
#     423             return result
#     424
#
# /home/local/stud/adilova/mypy/local/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(self, arg, alpha)
#     374         except (TypeError, ValueError) as exc:
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#     378     def to_rgba_array(self, c, alpha=None):
#
# ValueError: to_rgba: Invalid rgba arg "0"
# to_rgb: Invalid rgb arg "0"
# cannot convert argument to rgb sequence
