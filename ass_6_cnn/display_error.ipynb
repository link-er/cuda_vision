# %%
import numpy as np
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')

errors = np.loadtxt('mnist_le_net/errors.txt')
errors = np.transpose(errors)

plt.plot(errors[0], errors[1])
